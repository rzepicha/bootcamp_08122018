# %%
# !pip install pandas
# Out:
# ...
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import os

# %%
# !pip install openpyxl
# Out:
# ...
#   Running setup.py install for et-xmlfile: started
#     Running setup.py install for et-xmlfile: finished with status 'done'
#   Running setup.py install for openpyxl: started
#     Running setup.py install for openpyxl: finished with status 'done'
# ...
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
data=pd.read_csv(os.path.join(r'C:\Users\kurs\workspace\data\numpy_pandas\files_pandas_21_01_2017\titanic_train.csv'))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
data[['Name','Survived']]
# Out:
#                                                   Name  Survived
# 0                              Braund, Mr. Owen Harris         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                               Heikkinen, Miss. Laina         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                             Allen, Mr. William Henry         0
# 5                                     Moran, Mr. James         0
# 6                              McCarthy, Mr. Timothy J         0
# 7                       Palsson, Master. Gosta Leonard         0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)         1
# 10                     Sandstrom, Miss. Marguerite Rut         1
# 11                            Bonnell, Miss. Elizabeth         1
# 12                      Saundercock, Mr. William Henry         0
# ...

# %%
data[5:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
data[5:10:2]
# Out:
#    PassengerId  Survived  Pclass                                 Name     Sex  \
# 5            6         0       3                     Moran, Mr. James    male
# 7            8         0       3       Palsson, Master. Gosta Leonard    male
# 9           10         1       2  Nasser, Mrs. Nicholas (Adele Achem)  female
#
#     Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 5   NaN      0      0  330877   8.4583   NaN        Q
# 7   2.0      3      1  349909  21.0750   NaN        S
# 9  14.0      1      0  237736  30.0708   NaN        C

# %%
data.loc[5] #wybieram piąty wiersz
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
data.loc[5:10, 'Name']
# Out:
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.loc[5:10, :'Pclass']
# Out:
#     PassengerId  Survived  Pclass
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3

# %%
data.loc[5:10, 'Pclass':'Age']
# Out:
#     Pclass                                               Name     Sex   Age
# 5        3                                   Moran, Mr. James    male   NaN
# 6        1                            McCarthy, Mr. Timothy J    male  54.0
# 7        3                     Palsson, Master. Gosta Leonard    male   2.0
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10       3                    Sandstrom, Miss. Marguerite Rut  female   4.0

# %%
data.iloc[5,3]
# Out:
# 'Moran, Mr. James'

# %%
data.iloc[5:10, :3]
# Out:
#    PassengerId  Survived  Pclass
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2

# %%
data.iloc[range(0,50,5)]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 5             6         0       3
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...

# %%
data['Sex']=data['Sex'].astype("category")

# %%
data.loc[0,"Sex"]
# Out:
# 'male'

# %%
data.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 861      male
# 862    female
# 863    female
# 864      male
# 865    female
# 866    female
# 867      male
# 868      male
# 869      male
# 870      male
# 871    female
# 872      male
# 873      male
# 874    female
# 875    female
# 876      male
# 877      male
# 878      male
# 879    female
# 880    female
# 881      male
# 882    female
# 883      male
# 884      male
# 885    female
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# ...

# %%
data.Sex=data.Sex.cat.add_categories("unknow")

# %%
data.Sex
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 861      male
# 862    female
# 863    female
# 864      male
# 865    female
# 866    female
# 867      male
# 868      male
# 869      male
# 870      male
# 871    female
# 872      male
# 873      male
# 874    female
# 875    female
# 876      male
# 877      male
# 878      male
# 879    female
# 880    female
# 881      male
# 882    female
# 883      male
# 884      male
# 885    female
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# ...

# %%
data.Pclass.max()
# Out:
# 3

# %%
data=pd.read_csv(os.path.join(r'C:\Users\kurs\workspace\data\numpy_pandas\files_pandas_21_01_2017\titanic_train.csv'), dtype={"Pclass":np.int8})

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int8
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(4), int8(1), object(5)
# memory usage: 201.3 KB

# %%
data=pd.read_csv(os.path.join(r'C:\Users\kurs\workspace\data\numpy_pandas\files_pandas_21_01_2017\titanic_train.csv'),skiprows=1)

# %%
data
# Out:
#        1  0  3                            Braund, Mr. Owen Harris    male  \
# 0      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1      3  1  3                             Heikkinen, Miss. Laina  female
# 2      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3      5  0  3                           Allen, Mr. William Henry    male
# 4      6  0  3                                   Moran, Mr. James    male
# 5      7  0  1                            McCarthy, Mr. Timothy J    male
# 6      8  0  3                     Palsson, Master. Gosta Leonard    male
# 7      9  1  3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 8     10  1  2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 9     11  1  3                    Sandstrom, Miss. Marguerite Rut  female
# 10    12  1  1                           Bonnell, Miss. Elizabeth  female
# 11    13  0  3                     Saundercock, Mr. William Henry    male
# ...

# %%
data.Cabin.fillna("Deck")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f646ab5b28c6> in <module>
# ----> 1 data.Cabin.fillna("Deck")
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Cabin'

# %%
data=pd.read_csv(os.path.join(r'C:\Users\kurs\workspace\data\numpy_pandas\files_pandas_21_01_2017\titanic_train.csv'))

# %%
data.Cabin.fillna("Deck")
# Out:
# 0             Deck
# 1              C85
# 2             Deck
# 3             C123
# 4             Deck
# 5             Deck
# 6              E46
# 7             Deck
# 8             Deck
# 9             Deck
# 10              G6
# 11            C103
# 12            Deck
# 13            Deck
# 14            Deck
# 15            Deck
# 16            Deck
# 17            Deck
# 18            Deck
# 19            Deck
# 20            Deck
# 21             D56
# 22            Deck
# 23              A6
# 24            Deck
# 25            Deck
# 26            Deck
# 27     C23 C25 C27
# 28            Deck
# 29            Deck
#           ...
# 861           Deck
# 862            D17
# 863           Deck
# 864           Deck
# 865           Deck
# 866           Deck
# 867            A24
# 868           Deck
# 869           Deck
# 870           Deck
# 871            D35
# 872    B51 B53 B55
# 873           Deck
# 874           Deck
# 875           Deck
# 876           Deck
# ...

# %%
df2=pd.DataFrame([[1,2], [3,4]])
df2
# Out:
#    0  1
# 0  1  2
# 1  3  4

# %%
data[data['Cabin']=='Deck']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
